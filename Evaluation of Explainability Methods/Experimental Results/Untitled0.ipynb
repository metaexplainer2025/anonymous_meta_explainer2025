# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
comparison_Expplaining_df = pd.read_csv("/content/drive/My Drive/Explainability Methods/Evaluation of Explicability Methods/Experimental Results/Comparisons_ExMethods_Final_Format.csv")
comparison_GNNs_df = pd.read_csv("/content/drive/My Drive/Explainability Methods/Evaluation of Explicability Methods/Experimental Results/GCN_plus_GAP__HyperParameters.csv")

# %%
best_AUC_ROC = comparison_GNNs_df[comparison_GNNs_df['AUC-ROC'] == max(comparison_GNNs_df['AUC-ROC'])]
print("best_AUC_ROC: ", best_AUC_ROC)
# Out:
# best_AUC_ROC:     Datset Model Name              Model Description Weight_Initializer  \
# 34  MUTAG    GCN+GAP  ReLu(GCN1)+ReLu(GCN2)+GAP+FFN            normal_
#
#     K-Fold  Epochs        LR  DropOut Rate   Bias  Batch Size Loss Function  \
# 34       6     100  0.008522      0.377276  False          16           MSE
#
#      AUC-ROC   AUC-PRC       Acc  Avg Runing Time[Epochs]
# 34  0.800017  0.808211  0.714214                 0.053144

# %%
print(df.iloc[10, 0])
# Out:
# CF2

# %%
df.iloc[10, 0]= "CF\u00b2"

# %%
print(df["Explicability Method Name"])
# Out:
# 0               SA
# 1         GuidedBP
# 2              CAM
# 3         Grad-CAM
# 4     GNNExplainer
# 5      PGExplainer
# 6        GraphMask
# 7        SubGraphX
# 8              LRP
# 9     ExcitationBP
# 10             CF²
# Name: Explicability Method Name, dtype: object

# %%
df.to_csv("/content/drive/My Drive/Explainability Methods/Evaluation of Explicability Methods/Experimental Results/Comparisons_ExMethods_Final_Format.csv", index=False)
